# %%
from PIL import Image
from pathlib import Path
import argparse
import glob
import os
import pandas as pd
from re import search
import re

# %%
path = '/home/ubuntu/bucket/projects'
projdir = '2019_07_11_JUMP-CP-pilots'
batchname = '2020_11_16_Scope1_YokogawaUS'
batchpath=os.path.join(path, projdir,batchname)

# %%
plist = [f for f in os.listdir(os.path.join(path, projdir, batchname))]

platelist = []


outpath_list = []


for p in plist:


    pl = p.split("-")
    
    plate = '_'.join(pl)
    
    
    outpath = os.path.join(path, projdir, 'workspace', 'load_data_csv', batchname, plate)
    
    
    
#     def makedirectory():

#         try:
#             os.makedirs(outpath)

#             print("Directory", outpath, "is created")

#         except IOError:

#             print("Directory", outpath, "already exists")

#     directory = makedirectory()
    
    
    platelist.append(plate)
    
    outpath_list.append(outpath)

# %%
plist_path = [os.path.join(path, projdir, batchname, f, 'PECCU') for f in os.listdir(os.path.join(path, projdir, batchname))]

plist_path
# Out:
# ['/home/ubuntu/bucket/projects/2019_07_11_JUMP-CP-pilots/2020_11_16_Scope1_YokogawaUS/BRO0117014-3D-2x2x1-singleplane-10x_20201026_113115/PECCU',
#  '/home/ubuntu/bucket/projects/2019_07_11_JUMP-CP-pilots/2020_11_16_Scope1_YokogawaUS/BRO0117014-3D-2x2x1-singleplane-20x_20201026_113115/PECCU',
#  '/home/ubuntu/bucket/projects/2019_07_11_JUMP-CP-pilots/2020_11_16_Scope1_YokogawaUS/BRO0117033-3D-2x2x1-dpc-20x_20201023_151718/PECCU',
#  '/home/ubuntu/bucket/projects/2019_07_11_JUMP-CP-pilots/2020_11_16_Scope1_YokogawaUS/BRO0117033-3D-2x2x1-singleplane-20x_20201015_161709/PECCU',
#  '/home/ubuntu/bucket/projects/2019_07_11_JUMP-CP-pilots/2020_11_16_Scope1_YokogawaUS/BRO0117056-2x2x1-20x_20201022_110522/PECCU',
#  '/home/ubuntu/bucket/projects/2019_07_11_JUMP-CP-pilots/2020_11_16_Scope1_YokogawaUS/BRO0117056-3D-2x2x1-20x_20201022_173956/PECCU',
#  '/home/ubuntu/bucket/projects/2019_07_11_JUMP-CP-pilots/2020_11_16_Scope1_YokogawaUS/BRO0117059-40x_20201013_155609/PECCU',
#  '/home/ubuntu/bucket/projects/2019_07_11_JUMP-CP-pilots/2020_11_16_Scope1_YokogawaUS/BRO0117059_20X_20201010_140319/PECCU',
#  '/home/ubuntu/bucket/projects/2019_07_11_JUMP-CP-pilots/2020_11_16_Scope1_YokogawaUS/BRO01177034-20x_20201020_164856/PECCU']

# %%
os.listdir(fpath)
# Out:
# ['1038406002_PerkinElmer_CellCarrier-384.wpp',
#  'CellPaint_3D_2x2x1_singleplane_20x.mes',
#  'DC_DCAM#1_CAM1.tif',
#  'DC_DCAM#2_CAM2.tif',
#  'DC_DCAM#3_CAM3.tif',
#  'DC_DCAM#4_CAM4.tif',
#  'MeasurementData.mlf',
#  'MeasurementDetail.mrf',
#  'PECCU.wpi',
#  'PECCU_A01_T0001F001L01A01Z01C02.tif',
#  'PECCU_A01_T0001F001L01A01Z01C03.tif',
#  'PECCU_A01_T0001F001L01A02Z01C04.tif',
#  'PECCU_A01_T0001F001L01A02Z01C05.tif',
#  'PECCU_A01_T0001F001L01A03Z01C01.tif',
#  'PECCU_A01_T0001F002L01A01Z01C02.tif',
#  'PECCU_A01_T0001F002L01A01Z01C03.tif',
#  'PECCU_A01_T0001F002L01A02Z01C04.tif',
#  'PECCU_A01_T0001F002L01A02Z01C05.tif',
#  'PECCU_A01_T0001F002L01A03Z01C01.tif',
#  'PECCU_A01_T0001F003L01A01Z01C02.tif',
#  'PECCU_A01_T0001F003L01A01Z01C03.tif',
#  'PECCU_A01_T0001F003L01A02Z01C04.tif',
#  'PECCU_A01_T0001F003L01A02Z01C05.tif',
#  'PECCU_A01_T0001F003L01A03Z01C01.tif',
#  'PECCU_A01_T0001F004L01A01Z01C02.tif',
#  'PECCU_A01_T0001F004L01A01Z01C03.tif',
#  'PECCU_A01_T0001F004L01A02Z01C04.tif',
#  'PECCU_A01_T0001F004L01A02Z01C05.tif',
#  'PECCU_A01_T0001F004L01A03Z01C01.tif',
#  'PECCU_A01_T0001F005L01A01Z01C02.tif',
#  'PECCU_A01_T0001F005L01A01Z01C03.tif',
#  'PECCU_A01_T0001F005L01A02Z01C04.tif',
#  'PECCU_A01_T0001F005L01A02Z01C05.tif',
#  'PECCU_A01_T0001F005L01A03Z01C01.tif',
#  'PECCU_A01_T0001F006L01A01Z01C02.tif',
#  'PECCU_A01_T0001F006L01A01Z01C03.tif',
#  'PECCU_A01_T0001F006L01A02Z01C04.tif',
#  'PECCU_A01_T0001F006L01A02Z01C05.tif',
#  'PECCU_A01_T0001F006L01A03Z01C01.tif',
#  'PECCU_A01_T0001F007L01A01Z01C02.tif',
#  'PECCU_A01_T0001F007L01A01Z01C03.tif',
#  'PECCU_A01_T0001F007L01A02Z01C04.tif',
#  'PECCU_A01_T0001F007L01A02Z01C05.tif',
#  'PECCU_A01_T0001F007L01A03Z01C01.tif',
#  'PECCU_A01_T0001F008L01A01Z01C02.tif',
#  'PECCU_A01_T0001F008L01A01Z01C03.tif',
#  'PECCU_A01_T0001F008L01A02Z01C04.tif',
#  'PECCU_A01_T0001F008L01A02Z01C05.tif',
#  'PECCU_A01_T0001F008L01A03Z01C01.tif',
#  'PECCU_A01_T0001F009L01A01Z01C02.tif',
#  'PECCU_A01_T0001F009L01A01Z01C03.tif',
#  'PECCU_A01_T0001F009L01A02Z01C04.tif',
#  'PECCU_A01_T0001F009L01A02Z01C05.tif',
#  'PECCU_A01_T0001F009L01A03Z01C01.tif',
#  'PECCU_A02_T0001F001L01A01Z01C02.tif',
#  'PECCU_A02_T0001F001L01A01Z01C03.tif',
#  'PECCU_A02_T0001F001L01A02Z01C04.tif',
#  'PECCU_A02_T0001F001L01A02Z01C05.tif',
#  'PECCU_A02_T0001F001L01A03Z01C01.tif',
#  'PECCU_A02_T0001F002L01A01Z01C02.tif',
#  'PECCU_A02_T0001F002L01A01Z01C03.tif',
#  'PECCU_A02_T0001F002L01A02Z01C04.tif',
#  'PECCU_A02_T0001F002L01A02Z01C05.tif',
#  'PECCU_A02_T0001F002L01A03Z01C01.tif',
#  'PECCU_A02_T0001F003L01A01Z01C02.tif',
#  'PECCU_A02_T0001F003L01A01Z01C03.tif',
#  'PECCU_A02_T0001F003L01A02Z01C04.tif',
#  'PECCU_A02_T0001F003L01A02Z01C05.tif',
#  'PECCU_A02_T0001F003L01A03Z01C01.tif',
#  'PECCU_A02_T0001F004L01A01Z01C02.tif',
#  'PECCU_A02_T0001F004L01A01Z01C03.tif',
#  'PECCU_A02_T0001F004L01A02Z01C04.tif',
#  'PECCU_A02_T0001F004L01A02Z01C05.tif',
#  'PECCU_A02_T0001F004L01A03Z01C01.tif',
#  'PECCU_A02_T0001F005L01A01Z01C02.tif',
#  'PECCU_A02_T0001F005L01A01Z01C03.tif',
#  'PECCU_A02_T0001F005L01A02Z01C04.tif',
#  'PECCU_A02_T0001F005L01A02Z01C05.tif',
#  'PECCU_A02_T0001F005L01A03Z01C01.tif',
#  'PECCU_A02_T0001F006L01A01Z01C02.tif',
#  'PECCU_A02_T0001F006L01A01Z01C03.tif',
#  'PECCU_A02_T0001F006L01A02Z01C04.tif',
#  'PECCU_A02_T0001F006L01A02Z01C05.tif',
#  'PECCU_A02_T0001F006L01A03Z01C01.tif',
#  'PECCU_A02_T0001F007L01A01Z01C02.tif',
#  'PECCU_A02_T0001F007L01A01Z01C03.tif',
#  'PECCU_A02_T0001F007L01A02Z01C04.tif',
#  'PECCU_A02_T0001F007L01A02Z01C05.tif',
#  'PECCU_A02_T0001F007L01A03Z01C01.tif',
#  'PECCU_A02_T0001F008L01A01Z01C02.tif',
#  'PECCU_A02_T0001F008L01A01Z01C03.tif',
#  'PECCU_A02_T0001F008L01A02Z01C04.tif',
#  'PECCU_A02_T0001F008L01A02Z01C05.tif',
#  'PECCU_A02_T0001F008L01A03Z01C01.tif',
#  'PECCU_A02_T0001F009L01A01Z01C02.tif',
#  'PECCU_A02_T0001F009L01A01Z01C03.tif',
#  'PECCU_A02_T0001F009L01A02Z01C04.tif',
#  'PECCU_A02_T0001F009L01A02Z01C05.tif',
#  'PECCU_A02_T0001F009L01A03Z01C01.tif',
#  'PECCU_A03_T0001F001L01A01Z01C02.tif',
#  'PECCU_A03_T0001F001L01A01Z01C03.tif',
#  'PECCU_A03_T0001F001L01A02Z01C04.tif',
#  'PECCU_A03_T0001F001L01A02Z01C05.tif',
#  'PECCU_A03_T0001F001L01A03Z01C01.tif',
#  'PECCU_A03_T0001F002L01A01Z01C02.tif',
#  'PECCU_A03_T0001F002L01A01Z01C03.tif',
#  'PECCU_A03_T0001F002L01A02Z01C04.tif',
#  'PECCU_A03_T0001F002L01A02Z01C05.tif',
#  'PECCU_A03_T0001F002L01A03Z01C01.tif',
#  'PECCU_A03_T0001F003L01A01Z01C02.tif',
#  'PECCU_A03_T0001F003L01A01Z01C03.tif',
#  'PECCU_A03_T0001F003L01A02Z01C04.tif',
#  'PECCU_A03_T0001F003L01A02Z01C05.tif',
#  'PECCU_A03_T0001F003L01A03Z01C01.tif',
#  'PECCU_A03_T0001F004L01A01Z01C02.tif',
#  'PECCU_A03_T0001F004L01A01Z01C03.tif',
#  'PECCU_A03_T0001F004L01A02Z01C04.tif',
#  'PECCU_A03_T0001F004L01A02Z01C05.tif',
#  'PECCU_A03_T0001F004L01A03Z01C01.tif',
#  'PECCU_A03_T0001F005L01A01Z01C02.tif',
#  'PECCU_A03_T0001F005L01A01Z01C03.tif',
#  'PECCU_A03_T0001F005L01A02Z01C04.tif',
#  'PECCU_A03_T0001F005L01A02Z01C05.tif',
#  'PECCU_A03_T0001F005L01A03Z01C01.tif',
#  'PECCU_A03_T0001F006L01A01Z01C02.tif',
#  'PECCU_A03_T0001F006L01A01Z01C03.tif',
#  'PECCU_A03_T0001F006L01A02Z01C04.tif',
#  'PECCU_A03_T0001F006L01A02Z01C05.tif',
#  'PECCU_A03_T0001F006L01A03Z01C01.tif',
#  'PECCU_A03_T0001F007L01A01Z01C02.tif',
#  'PECCU_A03_T0001F007L01A01Z01C03.tif',
#  'PECCU_A03_T0001F007L01A02Z01C04.tif',
#  'PECCU_A03_T0001F007L01A02Z01C05.tif',
#  'PECCU_A03_T0001F007L01A03Z01C01.tif',
#  'PECCU_A03_T0001F008L01A01Z01C02.tif',
#  'PECCU_A03_T0001F008L01A01Z01C03.tif',
#  'PECCU_A03_T0001F008L01A02Z01C04.tif',
#  'PECCU_A03_T0001F008L01A02Z01C05.tif',
#  'PECCU_A03_T0001F008L01A03Z01C01.tif',
#  'PECCU_A03_T0001F009L01A01Z01C02.tif',
#  'PECCU_A03_T0001F009L01A01Z01C03.tif',
#  'PECCU_A03_T0001F009L01A02Z01C04.tif',
#  'PECCU_A03_T0001F009L01A02Z01C05.tif',
#  'PECCU_A03_T0001F009L01A03Z01C01.tif',
#  'PECCU_A04_T0001F001L01A01Z01C02.tif',
#  'PECCU_A04_T0001F001L01A01Z01C03.tif',
#  'PECCU_A04_T0001F001L01A02Z01C04.tif',
#  'PECCU_A04_T0001F001L01A02Z01C05.tif',
#  'PECCU_A04_T0001F001L01A03Z01C01.tif',
#  'PECCU_A04_T0001F002L01A01Z01C02.tif',
#  'PECCU_A04_T0001F002L01A01Z01C03.tif',
#  'PECCU_A04_T0001F002L01A02Z01C04.tif',
#  'PECCU_A04_T0001F002L01A02Z01C05.tif',
#  'PECCU_A04_T0001F002L01A03Z01C01.tif',
#  'PECCU_A04_T0001F003L01A01Z01C02.tif',
#  'PECCU_A04_T0001F003L01A01Z01C03.tif',
#  'PECCU_A04_T0001F003L01A02Z01C04.tif',
#  'PECCU_A04_T0001F003L01A02Z01C05.tif',
#  'PECCU_A04_T0001F003L01A03Z01C01.tif',
#  'PECCU_A04_T0001F004L01A01Z01C02.tif',
#  'PECCU_A04_T0001F004L01A01Z01C03.tif',
#  'PECCU_A04_T0001F004L01A02Z01C04.tif',
#  'PECCU_A04_T0001F004L01A02Z01C05.tif',
#  'PECCU_A04_T0001F004L01A03Z01C01.tif',
#  'PECCU_A04_T0001F005L01A01Z01C02.tif',
#  'PECCU_A04_T0001F005L01A01Z01C03.tif',
#  'PECCU_A04_T0001F005L01A02Z01C04.tif',
#  'PECCU_A04_T0001F005L01A02Z01C05.tif',
#  'PECCU_A04_T0001F005L01A03Z01C01.tif',
#  'PECCU_A04_T0001F006L01A01Z01C02.tif',
#  'PECCU_A04_T0001F006L01A01Z01C03.tif',
#  'PECCU_A04_T0001F006L01A02Z01C04.tif',
#  'PECCU_A04_T0001F006L01A02Z01C05.tif',
#  'PECCU_A04_T0001F006L01A03Z01C01.tif',
#  'PECCU_A04_T0001F007L01A01Z01C02.tif',
#  'PECCU_A04_T0001F007L01A01Z01C03.tif',
#  'PECCU_A04_T0001F007L01A02Z01C04.tif',
#  'PECCU_A04_T0001F007L01A02Z01C05.tif',
#  'PECCU_A04_T0001F007L01A03Z01C01.tif',
#  'PECCU_A04_T0001F008L01A01Z01C02.tif',
#  'PECCU_A04_T0001F008L01A01Z01C03.tif',
#  'PECCU_A04_T0001F008L01A02Z01C04.tif',
#  'PECCU_A04_T0001F008L01A02Z01C05.tif',
#  'PECCU_A04_T0001F008L01A03Z01C01.tif',
#  'PECCU_A04_T0001F009L01A01Z01C02.tif',
#  'PECCU_A04_T0001F009L01A01Z01C03.tif',
#  'PECCU_A04_T0001F009L01A02Z01C04.tif',
#  'PECCU_A04_T0001F009L01A02Z01C05.tif',
#  'PECCU_A04_T0001F009L01A03Z01C01.tif',
#  'PECCU_A05_T0001F001L01A01Z01C02.tif',
#  'PECCU_A05_T0001F001L01A01Z01C03.tif',
#  'PECCU_A05_T0001F001L01A02Z01C04.tif',
#  'PECCU_A05_T0001F001L01A02Z01C05.tif',
#  'PECCU_A05_T0001F001L01A03Z01C01.tif',
#  'PECCU_A05_T0001F002L01A01Z01C02.tif',
#  'PECCU_A05_T0001F002L01A01Z01C03.tif',
#  'PECCU_A05_T0001F002L01A02Z01C04.tif',
#  'PECCU_A05_T0001F002L01A02Z01C05.tif',
#  'PECCU_A05_T0001F002L01A03Z01C01.tif',
#  'PECCU_A05_T0001F003L01A01Z01C02.tif',
#  'PECCU_A05_T0001F003L01A01Z01C03.tif',
#  'PECCU_A05_T0001F003L01A02Z01C04.tif',
#  'PECCU_A05_T0001F003L01A02Z01C05.tif',
#  'PECCU_A05_T0001F003L01A03Z01C01.tif',
#  'PECCU_A05_T0001F004L01A01Z01C02.tif',
#  'PECCU_A05_T0001F004L01A01Z01C03.tif',
#  'PECCU_A05_T0001F004L01A02Z01C04.tif',
#  'PECCU_A05_T0001F004L01A02Z01C05.tif',
#  'PECCU_A05_T0001F004L01A03Z01C01.tif',
#  'PECCU_A05_T0001F005L01A01Z01C02.tif',
#  'PECCU_A05_T0001F005L01A01Z01C03.tif',
#  'PECCU_A05_T0001F005L01A02Z01C04.tif',
#  'PECCU_A05_T0001F005L01A02Z01C05.tif',
#  'PECCU_A05_T0001F005L01A03Z01C01.tif',
#  'PECCU_A05_T0001F006L01A01Z01C02.tif',
#  'PECCU_A05_T0001F006L01A01Z01C03.tif',
#  'PECCU_A05_T0001F006L01A02Z01C04.tif',
#  'PECCU_A05_T0001F006L01A02Z01C05.tif',
#  'PECCU_A05_T0001F006L01A03Z01C01.tif',
#  'PECCU_A05_T0001F007L01A01Z01C02.tif',
#  'PECCU_A05_T0001F007L01A01Z01C03.tif',
#  'PECCU_A05_T0001F007L01A02Z01C04.tif',
#  'PECCU_A05_T0001F007L01A02Z01C05.tif',
#  'PECCU_A05_T0001F007L01A03Z01C01.tif',
#  'PECCU_A05_T0001F008L01A01Z01C02.tif',
#  'PECCU_A05_T0001F008L01A01Z01C03.tif',
#  'PECCU_A05_T0001F008L01A02Z01C04.tif',
#  'PECCU_A05_T0001F008L01A02Z01C05.tif',
#  'PECCU_A05_T0001F008L01A03Z01C01.tif',
#  'PECCU_A05_T0001F009L01A01Z01C02.tif',
#  'PECCU_A05_T0001F009L01A01Z01C03.tif',
#  'PECCU_A05_T0001F009L01A02Z01C04.tif',
#  'PECCU_A05_T0001F009L01A02Z01C05.tif',
#  'PECCU_A05_T0001F009L01A03Z01C01.tif',
#  'PECCU_A06_T0001F001L01A01Z01C02.tif',
#  'PECCU_A06_T0001F001L01A01Z01C03.tif',
#  'PECCU_A06_T0001F001L01A02Z01C04.tif',
#  'PECCU_A06_T0001F001L01A02Z01C05.tif',
#  'PECCU_A06_T0001F001L01A03Z01C01.tif',
#  'PECCU_A06_T0001F002L01A01Z01C02.tif',
#  'PECCU_A06_T0001F002L01A01Z01C03.tif',
#  'PECCU_A06_T0001F002L01A02Z01C04.tif',
#  'PECCU_A06_T0001F002L01A02Z01C05.tif',
#  'PECCU_A06_T0001F002L01A03Z01C01.tif',
#  'PECCU_A06_T0001F003L01A01Z01C02.tif',
#  'PECCU_A06_T0001F003L01A01Z01C03.tif',
#  'PECCU_A06_T0001F003L01A02Z01C04.tif',
#  'PECCU_A06_T0001F003L01A02Z01C05.tif',
#  'PECCU_A06_T0001F003L01A03Z01C01.tif',
#  'PECCU_A06_T0001F004L01A01Z01C02.tif',
#  'PECCU_A06_T0001F004L01A01Z01C03.tif',
#  'PECCU_A06_T0001F004L01A02Z01C04.tif',
#  'PECCU_A06_T0001F004L01A02Z01C05.tif',
#  'PECCU_A06_T0001F004L01A03Z01C01.tif',
#  'PECCU_A06_T0001F005L01A01Z01C02.tif',
#  'PECCU_A06_T0001F005L01A01Z01C03.tif',
#  'PECCU_A06_T0001F005L01A02Z01C04.tif',
#  'PECCU_A06_T0001F005L01A02Z01C05.tif',
#  'PECCU_A06_T0001F005L01A03Z01C01.tif',
#  'PECCU_A06_T0001F006L01A01Z01C02.tif',
#  'PECCU_A06_T0001F006L01A01Z01C03.tif',
#  'PECCU_A06_T0001F006L01A02Z01C04.tif',
#  'PECCU_A06_T0001F006L01A02Z01C05.tif',
#  'PECCU_A06_T0001F006L01A03Z01C01.tif',
#  'PECCU_A06_T0001F007L01A01Z01C02.tif',
#  'PECCU_A06_T0001F007L01A01Z01C03.tif',
#  'PECCU_A06_T0001F007L01A02Z01C04.tif',
#  'PECCU_A06_T0001F007L01A02Z01C05.tif',
#  'PECCU_A06_T0001F007L01A03Z01C01.tif',
#  'PECCU_A06_T0001F008L01A01Z01C02.tif',
#  'PECCU_A06_T0001F008L01A01Z01C03.tif',
#  'PECCU_A06_T0001F008L01A02Z01C04.tif',
#  'PECCU_A06_T0001F008L01A02Z01C05.tif',
#  'PECCU_A06_T0001F008L01A03Z01C01.tif',
#  'PECCU_A06_T0001F009L01A01Z01C02.tif',
#  'PECCU_A06_T0001F009L01A01Z01C03.tif',
#  'PECCU_A06_T0001F009L01A02Z01C04.tif',
#  'PECCU_A06_T0001F009L01A02Z01C05.tif',
#  'PECCU_A06_T0001F009L01A03Z01C01.tif',
#  'PECCU_A07_T0001F001L01A01Z01C02.tif',
#  'PECCU_A07_T0001F001L01A01Z01C03.tif',
#  'PECCU_A07_T0001F001L01A02Z01C04.tif',
#  'PECCU_A07_T0001F001L01A02Z01C05.tif',
#  'PECCU_A07_T0001F001L01A03Z01C01.tif',
#  'PECCU_A07_T0001F002L01A01Z01C02.tif',
#  'PECCU_A07_T0001F002L01A01Z01C03.tif',
#  'PECCU_A07_T0001F002L01A02Z01C04.tif',
#  'PECCU_A07_T0001F002L01A02Z01C05.tif',
#  'PECCU_A07_T0001F002L01A03Z01C01.tif',
#  'PECCU_A07_T0001F003L01A01Z01C02.tif',
#  'PECCU_A07_T0001F003L01A01Z01C03.tif',
#  'PECCU_A07_T0001F003L01A02Z01C04.tif',
#  'PECCU_A07_T0001F003L01A02Z01C05.tif',
#  'PECCU_A07_T0001F003L01A03Z01C01.tif',
#  'PECCU_A07_T0001F004L01A01Z01C02.tif',
#  'PECCU_A07_T0001F004L01A01Z01C03.tif',
#  'PECCU_A07_T0001F004L01A02Z01C04.tif',
#  'PECCU_A07_T0001F004L01A02Z01C05.tif',
#  'PECCU_A07_T0001F004L01A03Z01C01.tif',
#  'PECCU_A07_T0001F005L01A01Z01C02.tif',
#  'PECCU_A07_T0001F005L01A01Z01C03.tif',
#  'PECCU_A07_T0001F005L01A02Z01C04.tif',
#  'PECCU_A07_T0001F005L01A02Z01C05.tif',
#  'PECCU_A07_T0001F005L01A03Z01C01.tif',
#  'PECCU_A07_T0001F006L01A01Z01C02.tif',
#  'PECCU_A07_T0001F006L01A01Z01C03.tif',
#  'PECCU_A07_T0001F006L01A02Z01C04.tif',
#  'PECCU_A07_T0001F006L01A02Z01C05.tif',
#  'PECCU_A07_T0001F006L01A03Z01C01.tif',
#  'PECCU_A07_T0001F007L01A01Z01C02.tif',
#  'PECCU_A07_T0001F007L01A01Z01C03.tif',
#  'PECCU_A07_T0001F007L01A02Z01C04.tif',
#  'PECCU_A07_T0001F007L01A02Z01C05.tif',
#  'PECCU_A07_T0001F007L01A03Z01C01.tif',
#  'PECCU_A07_T0001F008L01A01Z01C02.tif',
#  'PECCU_A07_T0001F008L01A01Z01C03.tif',
#  'PECCU_A07_T0001F008L01A02Z01C04.tif',
#  'PECCU_A07_T0001F008L01A02Z01C05.tif',
#  'PECCU_A07_T0001F008L01A03Z01C01.tif',
#  'PECCU_A07_T0001F009L01A01Z01C02.tif',
#  'PECCU_A07_T0001F009L01A01Z01C03.tif',
#  'PECCU_A07_T0001F009L01A02Z01C04.tif',
#  'PECCU_A07_T0001F009L01A02Z01C05.tif',
#  'PECCU_A07_T0001F009L01A03Z01C01.tif',
#  'PECCU_A08_T0001F001L01A01Z01C02.tif',
#  'PECCU_A08_T0001F001L01A01Z01C03.tif',
#  'PECCU_A08_T0001F001L01A02Z01C04.tif',
#  'PECCU_A08_T0001F001L01A02Z01C05.tif',
#  'PECCU_A08_T0001F001L01A03Z01C01.tif',
#  'PECCU_A08_T0001F002L01A01Z01C02.tif',
#  'PECCU_A08_T0001F002L01A01Z01C03.tif',
#  'PECCU_A08_T0001F002L01A02Z01C04.tif',
#  'PECCU_A08_T0001F002L01A02Z01C05.tif',
#  'PECCU_A08_T0001F002L01A03Z01C01.tif',
#  'PECCU_A08_T0001F003L01A01Z01C02.tif',
#  'PECCU_A08_T0001F003L01A01Z01C03.tif',
#  'PECCU_A08_T0001F003L01A02Z01C04.tif',
#  'PECCU_A08_T0001F003L01A02Z01C05.tif',
#  'PECCU_A08_T0001F003L01A03Z01C01.tif',
#  'PECCU_A08_T0001F004L01A01Z01C02.tif',
#  'PECCU_A08_T0001F004L01A01Z01C03.tif',
#  'PECCU_A08_T0001F004L01A02Z01C04.tif',
#  'PECCU_A08_T0001F004L01A02Z01C05.tif',
#  'PECCU_A08_T0001F004L01A03Z01C01.tif',
#  'PECCU_A08_T0001F005L01A01Z01C02.tif',
#  'PECCU_A08_T0001F005L01A01Z01C03.tif',
#  'PECCU_A08_T0001F005L01A02Z01C04.tif',
#  'PECCU_A08_T0001F005L01A02Z01C05.tif',
#  'PECCU_A08_T0001F005L01A03Z01C01.tif',
#  'PECCU_A08_T0001F006L01A01Z01C02.tif',
#  'PECCU_A08_T0001F006L01A01Z01C03.tif',
#  'PECCU_A08_T0001F006L01A02Z01C04.tif',
#  'PECCU_A08_T0001F006L01A02Z01C05.tif',
#  'PECCU_A08_T0001F006L01A03Z01C01.tif',
#  'PECCU_A08_T0001F007L01A01Z01C02.tif',
#  'PECCU_A08_T0001F007L01A01Z01C03.tif',
#  'PECCU_A08_T0001F007L01A02Z01C04.tif',
#  'PECCU_A08_T0001F007L01A02Z01C05.tif',
#  'PECCU_A08_T0001F007L01A03Z01C01.tif',
#  'PECCU_A08_T0001F008L01A01Z01C02.tif',
#  'PECCU_A08_T0001F008L01A01Z01C03.tif',
#  'PECCU_A08_T0001F008L01A02Z01C04.tif',
#  'PECCU_A08_T0001F008L01A02Z01C05.tif',
#  'PECCU_A08_T0001F008L01A03Z01C01.tif',
#  'PECCU_A08_T0001F009L01A01Z01C02.tif',
#  'PECCU_A08_T0001F009L01A01Z01C03.tif',
#  'PECCU_A08_T0001F009L01A02Z01C04.tif',
#  'PECCU_A08_T0001F009L01A02Z01C05.tif',
#  'PECCU_A08_T0001F009L01A03Z01C01.tif',
#  'PECCU_A09_T0001F001L01A01Z01C02.tif',
#  'PECCU_A09_T0001F001L01A01Z01C03.tif',
#  'PECCU_A09_T0001F001L01A02Z01C04.tif',
#  'PECCU_A09_T0001F001L01A02Z01C05.tif',
#  'PECCU_A09_T0001F001L01A03Z01C01.tif',
#  'PECCU_A09_T0001F002L01A01Z01C02.tif',
#  'PECCU_A09_T0001F002L01A01Z01C03.tif',
#  'PECCU_A09_T0001F002L01A02Z01C04.tif',
#  'PECCU_A09_T0001F002L01A02Z01C05.tif',
#  'PECCU_A09_T0001F002L01A03Z01C01.tif',
#  'PECCU_A09_T0001F003L01A01Z01C02.tif',
#  'PECCU_A09_T0001F003L01A01Z01C03.tif',
#  'PECCU_A09_T0001F003L01A02Z01C04.tif',
#  'PECCU_A09_T0001F003L01A02Z01C05.tif',
#  'PECCU_A09_T0001F003L01A03Z01C01.tif',
#  'PECCU_A09_T0001F004L01A01Z01C02.tif',
#  'PECCU_A09_T0001F004L01A01Z01C03.tif',
#  'PECCU_A09_T0001F004L01A02Z01C04.tif',
#  'PECCU_A09_T0001F004L01A02Z01C05.tif',
#  'PECCU_A09_T0001F004L01A03Z01C01.tif',
#  'PECCU_A09_T0001F005L01A01Z01C02.tif',
#  'PECCU_A09_T0001F005L01A01Z01C03.tif',
#  'PECCU_A09_T0001F005L01A02Z01C04.tif',
#  'PECCU_A09_T0001F005L01A02Z01C05.tif',
#  'PECCU_A09_T0001F005L01A03Z01C01.tif',
#  'PECCU_A09_T0001F006L01A01Z01C02.tif',
#  'PECCU_A09_T0001F006L01A01Z01C03.tif',
#  'PECCU_A09_T0001F006L01A02Z01C04.tif',
#  'PECCU_A09_T0001F006L01A02Z01C05.tif',
#  'PECCU_A09_T0001F006L01A03Z01C01.tif',
#  'PECCU_A09_T0001F007L01A01Z01C02.tif',
#  'PECCU_A09_T0001F007L01A01Z01C03.tif',
#  'PECCU_A09_T0001F007L01A02Z01C04.tif',
#  'PECCU_A09_T0001F007L01A02Z01C05.tif',
#  'PECCU_A09_T0001F007L01A03Z01C01.tif',
#  'PECCU_A09_T0001F008L01A01Z01C02.tif',
#  'PECCU_A09_T0001F008L01A01Z01C03.tif',
#  'PECCU_A09_T0001F008L01A02Z01C04.tif',
#  'PECCU_A09_T0001F008L01A02Z01C05.tif',
#  'PECCU_A09_T0001F008L01A03Z01C01.tif',
#  'PECCU_A09_T0001F009L01A01Z01C02.tif',
#  'PECCU_A09_T0001F009L01A01Z01C03.tif',
#  'PECCU_A09_T0001F009L01A02Z01C04.tif',
#  'PECCU_A09_T0001F009L01A02Z01C05.tif',
#  'PECCU_A09_T0001F009L01A03Z01C01.tif',
#  'PECCU_A10_T0001F001L01A01Z01C02.tif',
#  'PECCU_A10_T0001F001L01A01Z01C03.tif',
#  'PECCU_A10_T0001F001L01A02Z01C04.tif',
#  'PECCU_A10_T0001F001L01A02Z01C05.tif',
#  'PECCU_A10_T0001F001L01A03Z01C01.tif',
#  'PECCU_A10_T0001F002L01A01Z01C02.tif',
#  'PECCU_A10_T0001F002L01A01Z01C03.tif',
#  'PECCU_A10_T0001F002L01A02Z01C04.tif',
#  'PECCU_A10_T0001F002L01A02Z01C05.tif',
#  'PECCU_A10_T0001F002L01A03Z01C01.tif',
#  'PECCU_A10_T0001F003L01A01Z01C02.tif',
#  'PECCU_A10_T0001F003L01A01Z01C03.tif',
#  'PECCU_A10_T0001F003L01A02Z01C04.tif',
#  'PECCU_A10_T0001F003L01A02Z01C05.tif',
#  'PECCU_A10_T0001F003L01A03Z01C01.tif',
#  'PECCU_A10_T0001F004L01A01Z01C02.tif',
#  'PECCU_A10_T0001F004L01A01Z01C03.tif',
#  'PECCU_A10_T0001F004L01A02Z01C04.tif',
#  'PECCU_A10_T0001F004L01A02Z01C05.tif',
#  'PECCU_A10_T0001F004L01A03Z01C01.tif',
#  'PECCU_A10_T0001F005L01A01Z01C02.tif',
#  'PECCU_A10_T0001F005L01A01Z01C03.tif',
#  'PECCU_A10_T0001F005L01A02Z01C04.tif',
#  'PECCU_A10_T0001F005L01A02Z01C05.tif',
#  'PECCU_A10_T0001F005L01A03Z01C01.tif',
#  'PECCU_A10_T0001F006L01A01Z01C02.tif',
#  'PECCU_A10_T0001F006L01A01Z01C03.tif',
#  'PECCU_A10_T0001F006L01A02Z01C04.tif',
#  'PECCU_A10_T0001F006L01A02Z01C05.tif',
#  'PECCU_A10_T0001F006L01A03Z01C01.tif',
#  'PECCU_A10_T0001F007L01A01Z01C02.tif',
#  'PECCU_A10_T0001F007L01A01Z01C03.tif',
#  'PECCU_A10_T0001F007L01A02Z01C04.tif',
#  'PECCU_A10_T0001F007L01A02Z01C05.tif',
#  'PECCU_A10_T0001F007L01A03Z01C01.tif',
#  'PECCU_A10_T0001F008L01A01Z01C02.tif',
#  'PECCU_A10_T0001F008L01A01Z01C03.tif',
#  'PECCU_A10_T0001F008L01A02Z01C04.tif',
#  'PECCU_A10_T0001F008L01A02Z01C05.tif',
#  'PECCU_A10_T0001F008L01A03Z01C01.tif',
#  'PECCU_A10_T0001F009L01A01Z01C02.tif',
#  'PECCU_A10_T0001F009L01A01Z01C03.tif',
#  'PECCU_A10_T0001F009L01A02Z01C04.tif',
#  'PECCU_A10_T0001F009L01A02Z01C05.tif',
#  'PECCU_A10_T0001F009L01A03Z01C01.tif',
#  'PECCU_A11_T0001F001L01A01Z01C02.tif',
#  'PECCU_A11_T0001F001L01A01Z01C03.tif',
#  'PECCU_A11_T0001F001L01A02Z01C04.tif',
#  'PECCU_A11_T0001F001L01A02Z01C05.tif',
#  'PECCU_A11_T0001F001L01A03Z01C01.tif',
#  'PECCU_A11_T0001F002L01A01Z01C02.tif',
#  'PECCU_A11_T0001F002L01A01Z01C03.tif',
#  'PECCU_A11_T0001F002L01A02Z01C04.tif',
#  'PECCU_A11_T0001F002L01A02Z01C05.tif',
#  'PECCU_A11_T0001F002L01A03Z01C01.tif',
#  'PECCU_A11_T0001F003L01A01Z01C02.tif',
#  'PECCU_A11_T0001F003L01A01Z01C03.tif',
#  'PECCU_A11_T0001F003L01A02Z01C04.tif',
#  'PECCU_A11_T0001F003L01A02Z01C05.tif',
#  'PECCU_A11_T0001F003L01A03Z01C01.tif',
#  'PECCU_A11_T0001F004L01A01Z01C02.tif',
#  'PECCU_A11_T0001F004L01A01Z01C03.tif',
#  'PECCU_A11_T0001F004L01A02Z01C04.tif',
#  'PECCU_A11_T0001F004L01A02Z01C05.tif',
#  'PECCU_A11_T0001F004L01A03Z01C01.tif',
#  'PECCU_A11_T0001F005L01A01Z01C02.tif',
#  'PECCU_A11_T0001F005L01A01Z01C03.tif',
#  'PECCU_A11_T0001F005L01A02Z01C04.tif',
#  'PECCU_A11_T0001F005L01A02Z01C05.tif',
#  'PECCU_A11_T0001F005L01A03Z01C01.tif',
#  'PECCU_A11_T0001F006L01A01Z01C02.tif',
#  'PECCU_A11_T0001F006L01A01Z01C03.tif',
#  'PECCU_A11_T0001F006L01A02Z01C04.tif',
#  'PECCU_A11_T0001F006L01A02Z01C05.tif',
#  'PECCU_A11_T0001F006L01A03Z01C01.tif',
#  'PECCU_A11_T0001F007L01A01Z01C02.tif',
#  'PECCU_A11_T0001F007L01A01Z01C03.tif',
#  'PECCU_A11_T0001F007L01A02Z01C04.tif',
#  'PECCU_A11_T0001F007L01A02Z01C05.tif',
#  'PECCU_A11_T0001F007L01A03Z01C01.tif',
#  'PECCU_A11_T0001F008L01A01Z01C02.tif',
#  'PECCU_A11_T0001F008L01A01Z01C03.tif',
#  'PECCU_A11_T0001F008L01A02Z01C04.tif',
#  'PECCU_A11_T0001F008L01A02Z01C05.tif',
#  'PECCU_A11_T0001F008L01A03Z01C01.tif',
#  'PECCU_A11_T0001F009L01A01Z01C02.tif',
#  'PECCU_A11_T0001F009L01A01Z01C03.tif',
#  'PECCU_A11_T0001F009L01A02Z01C04.tif',
#  'PECCU_A11_T0001F009L01A02Z01C05.tif',
#  'PECCU_A11_T0001F009L01A03Z01C01.tif',
#  'PECCU_A12_T0001F001L01A01Z01C02.tif',
#  'PECCU_A12_T0001F001L01A01Z01C03.tif',
#  'PECCU_A12_T0001F001L01A02Z01C04.tif',
#  'PECCU_A12_T0001F001L01A02Z01C05.tif',
#  'PECCU_A12_T0001F001L01A03Z01C01.tif',
#  'PECCU_A12_T0001F002L01A01Z01C02.tif',
#  'PECCU_A12_T0001F002L01A01Z01C03.tif',
#  'PECCU_A12_T0001F002L01A02Z01C04.tif',
#  'PECCU_A12_T0001F002L01A02Z01C05.tif',
#  'PECCU_A12_T0001F002L01A03Z01C01.tif',
#  'PECCU_A12_T0001F003L01A01Z01C02.tif',
#  'PECCU_A12_T0001F003L01A01Z01C03.tif',
#  'PECCU_A12_T0001F003L01A02Z01C04.tif',
#  'PECCU_A12_T0001F003L01A02Z01C05.tif',
#  'PECCU_A12_T0001F003L01A03Z01C01.tif',
#  'PECCU_A12_T0001F004L01A01Z01C02.tif',
#  'PECCU_A12_T0001F004L01A01Z01C03.tif',
#  'PECCU_A12_T0001F004L01A02Z01C04.tif',
#  'PECCU_A12_T0001F004L01A02Z01C05.tif',
#  'PECCU_A12_T0001F004L01A03Z01C01.tif',
#  'PECCU_A12_T0001F005L01A01Z01C02.tif',
#  'PECCU_A12_T0001F005L01A01Z01C03.tif',
#  'PECCU_A12_T0001F005L01A02Z01C04.tif',
#  'PECCU_A12_T0001F005L01A02Z01C05.tif',
#  'PECCU_A12_T0001F005L01A03Z01C01.tif',
#  'PECCU_A12_T0001F006L01A01Z01C02.tif',
#  'PECCU_A12_T0001F006L01A01Z01C03.tif',
#  'PECCU_A12_T0001F006L01A02Z01C04.tif',
#  'PECCU_A12_T0001F006L01A02Z01C05.tif',
#  'PECCU_A12_T0001F006L01A03Z01C01.tif',
#  'PECCU_A12_T0001F007L01A01Z01C02.tif',
#  'PECCU_A12_T0001F007L01A01Z01C03.tif',
#  'PECCU_A12_T0001F007L01A02Z01C04.tif',
#  'PECCU_A12_T0001F007L01A02Z01C05.tif',
#  'PECCU_A12_T0001F007L01A03Z01C01.tif',
#  'PECCU_A12_T0001F008L01A01Z01C02.tif',
#  'PECCU_A12_T0001F008L01A01Z01C03.tif',
#  'PECCU_A12_T0001F008L01A02Z01C04.tif',
#  'PECCU_A12_T0001F008L01A02Z01C05.tif',
#  'PECCU_A12_T0001F008L01A03Z01C01.tif',
#  'PECCU_A12_T0001F009L01A01Z01C02.tif',
#  'PECCU_A12_T0001F009L01A01Z01C03.tif',
#  'PECCU_A12_T0001F009L01A02Z01C04.tif',
#  'PECCU_A12_T0001F009L01A02Z01C05.tif',
#  'PECCU_A12_T0001F009L01A03Z01C01.tif',
#  'PECCU_A13_T0001F001L01A01Z01C02.tif',
#  'PECCU_A13_T0001F001L01A01Z01C03.tif',
#  'PECCU_A13_T0001F001L01A02Z01C04.tif',
#  'PECCU_A13_T0001F001L01A02Z01C05.tif',
#  'PECCU_A13_T0001F001L01A03Z01C01.tif',
#  'PECCU_A13_T0001F002L01A01Z01C02.tif',
#  'PECCU_A13_T0001F002L01A01Z01C03.tif',
#  'PECCU_A13_T0001F002L01A02Z01C04.tif',
#  'PECCU_A13_T0001F002L01A02Z01C05.tif',
#  'PECCU_A13_T0001F002L01A03Z01C01.tif',
#  'PECCU_A13_T0001F003L01A01Z01C02.tif',
#  'PECCU_A13_T0001F003L01A01Z01C03.tif',
#  'PECCU_A13_T0001F003L01A02Z01C04.tif',
#  'PECCU_A13_T0001F003L01A02Z01C05.tif',
#  'PECCU_A13_T0001F003L01A03Z01C01.tif',
#  'PECCU_A13_T0001F004L01A01Z01C02.tif',
#  'PECCU_A13_T0001F004L01A01Z01C03.tif',
#  'PECCU_A13_T0001F004L01A02Z01C04.tif',
#  'PECCU_A13_T0001F004L01A02Z01C05.tif',
#  'PECCU_A13_T0001F004L01A03Z01C01.tif',
#  'PECCU_A13_T0001F005L01A01Z01C02.tif',
#  'PECCU_A13_T0001F005L01A01Z01C03.tif',
#  'PECCU_A13_T0001F005L01A02Z01C04.tif',
#  'PECCU_A13_T0001F005L01A02Z01C05.tif',
#  'PECCU_A13_T0001F005L01A03Z01C01.tif',
#  'PECCU_A13_T0001F006L01A01Z01C02.tif',
#  'PECCU_A13_T0001F006L01A01Z01C03.tif',
#  'PECCU_A13_T0001F006L01A02Z01C04.tif',
#  'PECCU_A13_T0001F006L01A02Z01C05.tif',
#  'PECCU_A13_T0001F006L01A03Z01C01.tif',
#  'PECCU_A13_T0001F007L01A01Z01C02.tif',
#  'PECCU_A13_T0001F007L01A01Z01C03.tif',
#  'PECCU_A13_T0001F007L01A02Z01C04.tif',
#  'PECCU_A13_T0001F007L01A02Z01C05.tif',
#  'PECCU_A13_T0001F007L01A03Z01C01.tif',
#  'PECCU_A13_T0001F008L01A01Z01C02.tif',
#  'PECCU_A13_T0001F008L01A01Z01C03.tif',
#  'PECCU_A13_T0001F008L01A02Z01C04.tif',
#  'PECCU_A13_T0001F008L01A02Z01C05.tif',
#  'PECCU_A13_T0001F008L01A03Z01C01.tif',
#  'PECCU_A13_T0001F009L01A01Z01C02.tif',
#  'PECCU_A13_T0001F009L01A01Z01C03.tif',
#  'PECCU_A13_T0001F009L01A02Z01C04.tif',
#  'PECCU_A13_T0001F009L01A02Z01C05.tif',
#  'PECCU_A13_T0001F009L01A03Z01C01.tif',
#  'PECCU_A14_T0001F001L01A01Z01C02.tif',
#  'PECCU_A14_T0001F001L01A01Z01C03.tif',
#  'PECCU_A14_T0001F001L01A02Z01C04.tif',
#  'PECCU_A14_T0001F001L01A02Z01C05.tif',
#  'PECCU_A14_T0001F001L01A03Z01C01.tif',
#  'PECCU_A14_T0001F002L01A01Z01C02.tif',
#  'PECCU_A14_T0001F002L01A01Z01C03.tif',
#  'PECCU_A14_T0001F002L01A02Z01C04.tif',
#  'PECCU_A14_T0001F002L01A02Z01C05.tif',
#  'PECCU_A14_T0001F002L01A03Z01C01.tif',
#  'PECCU_A14_T0001F003L01A01Z01C02.tif',
#  'PECCU_A14_T0001F003L01A01Z01C03.tif',
#  'PECCU_A14_T0001F003L01A02Z01C04.tif',
#  'PECCU_A14_T0001F003L01A02Z01C05.tif',
#  'PECCU_A14_T0001F003L01A03Z01C01.tif',
#  'PECCU_A14_T0001F004L01A01Z01C02.tif',
#  'PECCU_A14_T0001F004L01A01Z01C03.tif',
#  'PECCU_A14_T0001F004L01A02Z01C04.tif',
#  'PECCU_A14_T0001F004L01A02Z01C05.tif',
#  'PECCU_A14_T0001F004L01A03Z01C01.tif',
#  'PECCU_A14_T0001F005L01A01Z01C02.tif',
#  'PECCU_A14_T0001F005L01A01Z01C03.tif',
#  'PECCU_A14_T0001F005L01A02Z01C04.tif',
#  'PECCU_A14_T0001F005L01A02Z01C05.tif',
#  'PECCU_A14_T0001F005L01A03Z01C01.tif',
#  'PECCU_A14_T0001F006L01A01Z01C02.tif',
#  'PECCU_A14_T0001F006L01A01Z01C03.tif',
#  'PECCU_A14_T0001F006L01A02Z01C04.tif',
#  'PECCU_A14_T0001F006L01A02Z01C05.tif',
#  'PECCU_A14_T0001F006L01A03Z01C01.tif',
#  'PECCU_A14_T0001F007L01A01Z01C02.tif',
#  'PECCU_A14_T0001F007L01A01Z01C03.tif',
#  'PECCU_A14_T0001F007L01A02Z01C04.tif',
#  'PECCU_A14_T0001F007L01A02Z01C05.tif',
#  'PECCU_A14_T0001F007L01A03Z01C01.tif',
#  'PECCU_A14_T0001F008L01A01Z01C02.tif',
#  'PECCU_A14_T0001F008L01A01Z01C03.tif',
#  'PECCU_A14_T0001F008L01A02Z01C04.tif',
#  'PECCU_A14_T0001F008L01A02Z01C05.tif',
#  'PECCU_A14_T0001F008L01A03Z01C01.tif',
#  'PECCU_A14_T0001F009L01A01Z01C02.tif',
#  'PECCU_A14_T0001F009L01A01Z01C03.tif',
#  'PECCU_A14_T0001F009L01A02Z01C04.tif',
#  'PECCU_A14_T0001F009L01A02Z01C05.tif',
#  'PECCU_A14_T0001F009L01A03Z01C01.tif',
#  'PECCU_A15_T0001F001L01A01Z01C02.tif',
#  'PECCU_A15_T0001F001L01A01Z01C03.tif',
#  'PECCU_A15_T0001F001L01A02Z01C04.tif',
#  'PECCU_A15_T0001F001L01A02Z01C05.tif',
#  'PECCU_A15_T0001F001L01A03Z01C01.tif',
#  'PECCU_A15_T0001F002L01A01Z01C02.tif',
#  'PECCU_A15_T0001F002L01A01Z01C03.tif',
#  'PECCU_A15_T0001F002L01A02Z01C04.tif',
#  'PECCU_A15_T0001F002L01A02Z01C05.tif',
#  'PECCU_A15_T0001F002L01A03Z01C01.tif',
#  'PECCU_A15_T0001F003L01A01Z01C02.tif',
#  'PECCU_A15_T0001F003L01A01Z01C03.tif',
#  'PECCU_A15_T0001F003L01A02Z01C04.tif',
#  'PECCU_A15_T0001F003L01A02Z01C05.tif',
#  'PECCU_A15_T0001F003L01A03Z01C01.tif',
#  'PECCU_A15_T0001F004L01A01Z01C02.tif',
#  'PECCU_A15_T0001F004L01A01Z01C03.tif',
#  'PECCU_A15_T0001F004L01A02Z01C04.tif',
#  'PECCU_A15_T0001F004L01A02Z01C05.tif',
#  'PECCU_A15_T0001F004L01A03Z01C01.tif',
#  'PECCU_A15_T0001F005L01A01Z01C02.tif',
#  'PECCU_A15_T0001F005L01A01Z01C03.tif',
#  'PECCU_A15_T0001F005L01A02Z01C04.tif',
#  'PECCU_A15_T0001F005L01A02Z01C05.tif',
#  'PECCU_A15_T0001F005L01A03Z01C01.tif',
#  'PECCU_A15_T0001F006L01A01Z01C02.tif',
#  'PECCU_A15_T0001F006L01A01Z01C03.tif',
#  'PECCU_A15_T0001F006L01A02Z01C04.tif',
#  'PECCU_A15_T0001F006L01A02Z01C05.tif',
#  'PECCU_A15_T0001F006L01A03Z01C01.tif',
#  'PECCU_A15_T0001F007L01A01Z01C02.tif',
#  'PECCU_A15_T0001F007L01A01Z01C03.tif',
#  'PECCU_A15_T0001F007L01A02Z01C04.tif',
#  'PECCU_A15_T0001F007L01A02Z01C05.tif',
#  'PECCU_A15_T0001F007L01A03Z01C01.tif',
#  'PECCU_A15_T0001F008L01A01Z01C02.tif',
#  'PECCU_A15_T0001F008L01A01Z01C03.tif',
#  'PECCU_A15_T0001F008L01A02Z01C04.tif',
#  'PECCU_A15_T0001F008L01A02Z01C05.tif',
#  'PECCU_A15_T0001F008L01A03Z01C01.tif',
#  'PECCU_A15_T0001F009L01A01Z01C02.tif',
#  'PECCU_A15_T0001F009L01A01Z01C03.tif',
#  'PECCU_A15_T0001F009L01A02Z01C04.tif',
#  'PECCU_A15_T0001F009L01A02Z01C05.tif',
#  'PECCU_A15_T0001F009L01A03Z01C01.tif',
#  'PECCU_A16_T0001F001L01A01Z01C02.tif',
#  'PECCU_A16_T0001F001L01A01Z01C03.tif',
#  'PECCU_A16_T0001F001L01A02Z01C04.tif',
#  'PECCU_A16_T0001F001L01A02Z01C05.tif',
#  'PECCU_A16_T0001F001L01A03Z01C01.tif',
#  'PECCU_A16_T0001F002L01A01Z01C02.tif',
#  'PECCU_A16_T0001F002L01A01Z01C03.tif',
#  'PECCU_A16_T0001F002L01A02Z01C04.tif',
#  'PECCU_A16_T0001F002L01A02Z01C05.tif',
#  'PECCU_A16_T0001F002L01A03Z01C01.tif',
#  'PECCU_A16_T0001F003L01A01Z01C02.tif',
#  'PECCU_A16_T0001F003L01A01Z01C03.tif',
#  'PECCU_A16_T0001F003L01A02Z01C04.tif',
#  'PECCU_A16_T0001F003L01A02Z01C05.tif',
#  'PECCU_A16_T0001F003L01A03Z01C01.tif',
#  'PECCU_A16_T0001F004L01A01Z01C02.tif',
#  'PECCU_A16_T0001F004L01A01Z01C03.tif',
#  'PECCU_A16_T0001F004L01A02Z01C04.tif',
#  'PECCU_A16_T0001F004L01A02Z01C05.tif',
#  'PECCU_A16_T0001F004L01A03Z01C01.tif',
#  'PECCU_A16_T0001F005L01A01Z01C02.tif',
#  'PECCU_A16_T0001F005L01A01Z01C03.tif',
#  'PECCU_A16_T0001F005L01A02Z01C04.tif',
#  'PECCU_A16_T0001F005L01A02Z01C05.tif',
#  'PECCU_A16_T0001F005L01A03Z01C01.tif',
#  'PECCU_A16_T0001F006L01A01Z01C02.tif',
#  'PECCU_A16_T0001F006L01A01Z01C03.tif',
#  'PECCU_A16_T0001F006L01A02Z01C04.tif',
#  'PECCU_A16_T0001F006L01A02Z01C05.tif',
#  'PECCU_A16_T0001F006L01A03Z01C01.tif',
#  'PECCU_A16_T0001F007L01A01Z01C02.tif',
#  'PECCU_A16_T0001F007L01A01Z01C03.tif',
#  'PECCU_A16_T0001F007L01A02Z01C04.tif',
#  'PECCU_A16_T0001F007L01A02Z01C05.tif',
#  'PECCU_A16_T0001F007L01A03Z01C01.tif',
#  'PECCU_A16_T0001F008L01A01Z01C02.tif',
#  'PECCU_A16_T0001F008L01A01Z01C03.tif',
#  'PECCU_A16_T0001F008L01A02Z01C04.tif',
#  'PECCU_A16_T0001F008L01A02Z01C05.tif',
#  'PECCU_A16_T0001F008L01A03Z01C01.tif',
#  'PECCU_A16_T0001F009L01A01Z01C02.tif',
#  'PECCU_A16_T0001F009L01A01Z01C03.tif',
#  'PECCU_A16_T0001F009L01A02Z01C04.tif',
#  'PECCU_A16_T0001F009L01A02Z01C05.tif',
#  'PECCU_A16_T0001F009L01A03Z01C01.tif',
#  'PECCU_A17_T0001F001L01A01Z01C02.tif',
#  'PECCU_A17_T0001F001L01A01Z01C03.tif',
#  'PECCU_A17_T0001F001L01A02Z01C04.tif',
#  'PECCU_A17_T0001F001L01A02Z01C05.tif',
#  'PECCU_A17_T0001F001L01A03Z01C01.tif',
#  'PECCU_A17_T0001F002L01A01Z01C02.tif',
#  'PECCU_A17_T0001F002L01A01Z01C03.tif',
#  'PECCU_A17_T0001F002L01A02Z01C04.tif',
#  'PECCU_A17_T0001F002L01A02Z01C05.tif',
#  'PECCU_A17_T0001F002L01A03Z01C01.tif',
#  'PECCU_A17_T0001F003L01A01Z01C02.tif',
#  'PECCU_A17_T0001F003L01A01Z01C03.tif',
#  'PECCU_A17_T0001F003L01A02Z01C04.tif',
#  'PECCU_A17_T0001F003L01A02Z01C05.tif',
#  'PECCU_A17_T0001F003L01A03Z01C01.tif',
#  'PECCU_A17_T0001F004L01A01Z01C02.tif',
#  'PECCU_A17_T0001F004L01A01Z01C03.tif',
#  'PECCU_A17_T0001F004L01A02Z01C04.tif',
#  'PECCU_A17_T0001F004L01A02Z01C05.tif',
#  'PECCU_A17_T0001F004L01A03Z01C01.tif',
#  'PECCU_A17_T0001F005L01A01Z01C02.tif',
#  'PECCU_A17_T0001F005L01A01Z01C03.tif',
#  'PECCU_A17_T0001F005L01A02Z01C04.tif',
#  'PECCU_A17_T0001F005L01A02Z01C05.tif',
#  'PECCU_A17_T0001F005L01A03Z01C01.tif',
#  'PECCU_A17_T0001F006L01A01Z01C02.tif',
#  'PECCU_A17_T0001F006L01A01Z01C03.tif',
#  'PECCU_A17_T0001F006L01A02Z01C04.tif',
#  'PECCU_A17_T0001F006L01A02Z01C05.tif',
#  'PECCU_A17_T0001F006L01A03Z01C01.tif',
#  'PECCU_A17_T0001F007L01A01Z01C02.tif',
#  'PECCU_A17_T0001F007L01A01Z01C03.tif',
#  'PECCU_A17_T0001F007L01A02Z01C04.tif',
#  'PECCU_A17_T0001F007L01A02Z01C05.tif',
#  'PECCU_A17_T0001F007L01A03Z01C01.tif',
#  'PECCU_A17_T0001F008L01A01Z01C02.tif',
#  'PECCU_A17_T0001F008L01A01Z01C03.tif',
#  'PECCU_A17_T0001F008L01A02Z01C04.tif',
#  'PECCU_A17_T0001F008L01A02Z01C05.tif',
#  'PECCU_A17_T0001F008L01A03Z01C01.tif',
#  'PECCU_A17_T0001F009L01A01Z01C02.tif',
#  'PECCU_A17_T0001F009L01A01Z01C03.tif',
#  'PECCU_A17_T0001F009L01A02Z01C04.tif',
#  'PECCU_A17_T0001F009L01A02Z01C05.tif',
#  'PECCU_A17_T0001F009L01A03Z01C01.tif',
#  'PECCU_A18_T0001F001L01A01Z01C02.tif',
#  'PECCU_A18_T0001F001L01A01Z01C03.tif',
#  'PECCU_A18_T0001F001L01A02Z01C04.tif',
#  'PECCU_A18_T0001F001L01A02Z01C05.tif',
#  'PECCU_A18_T0001F001L01A03Z01C01.tif',
#  'PECCU_A18_T0001F002L01A01Z01C02.tif',
#  'PECCU_A18_T0001F002L01A01Z01C03.tif',
#  'PECCU_A18_T0001F002L01A02Z01C04.tif',
#  'PECCU_A18_T0001F002L01A02Z01C05.tif',
#  'PECCU_A18_T0001F002L01A03Z01C01.tif',
#  'PECCU_A18_T0001F003L01A01Z01C02.tif',
#  'PECCU_A18_T0001F003L01A01Z01C03.tif',
#  'PECCU_A18_T0001F003L01A02Z01C04.tif',
#  'PECCU_A18_T0001F003L01A02Z01C05.tif',
#  'PECCU_A18_T0001F003L01A03Z01C01.tif',
#  'PECCU_A18_T0001F004L01A01Z01C02.tif',
#  'PECCU_A18_T0001F004L01A01Z01C03.tif',
#  'PECCU_A18_T0001F004L01A02Z01C04.tif',
#  'PECCU_A18_T0001F004L01A02Z01C05.tif',
#  'PECCU_A18_T0001F004L01A03Z01C01.tif',
#  'PECCU_A18_T0001F005L01A01Z01C02.tif',
#  'PECCU_A18_T0001F005L01A01Z01C03.tif',
#  'PECCU_A18_T0001F005L01A02Z01C04.tif',
#  'PECCU_A18_T0001F005L01A02Z01C05.tif',
#  'PECCU_A18_T0001F005L01A03Z01C01.tif',
#  'PECCU_A18_T0001F006L01A01Z01C02.tif',
#  'PECCU_A18_T0001F006L01A01Z01C03.tif',
#  'PECCU_A18_T0001F006L01A02Z01C04.tif',
#  'PECCU_A18_T0001F006L01A02Z01C05.tif',
#  'PECCU_A18_T0001F006L01A03Z01C01.tif',
#  'PECCU_A18_T0001F007L01A01Z01C02.tif',
#  'PECCU_A18_T0001F007L01A01Z01C03.tif',
#  'PECCU_A18_T0001F007L01A02Z01C04.tif',
#  'PECCU_A18_T0001F007L01A02Z01C05.tif',
#  'PECCU_A18_T0001F007L01A03Z01C01.tif',
#  'PECCU_A18_T0001F008L01A01Z01C02.tif',
#  'PECCU_A18_T0001F008L01A01Z01C03.tif',
#  'PECCU_A18_T0001F008L01A02Z01C04.tif',
#  'PECCU_A18_T0001F008L01A02Z01C05.tif',
#  'PECCU_A18_T0001F008L01A03Z01C01.tif',
#  'PECCU_A18_T0001F009L01A01Z01C02.tif',
#  'PECCU_A18_T0001F009L01A01Z01C03.tif',
#  'PECCU_A18_T0001F009L01A02Z01C04.tif',
#  'PECCU_A18_T0001F009L01A02Z01C05.tif',
#  'PECCU_A18_T0001F009L01A03Z01C01.tif',
#  'PECCU_A19_T0001F001L01A01Z01C02.tif',
#  'PECCU_A19_T0001F001L01A01Z01C03.tif',
#  'PECCU_A19_T0001F001L01A02Z01C04.tif',
#  'PECCU_A19_T0001F001L01A02Z01C05.tif',
#  'PECCU_A19_T0001F001L01A03Z01C01.tif',
#  'PECCU_A19_T0001F002L01A01Z01C02.tif',
#  'PECCU_A19_T0001F002L01A01Z01C03.tif',
#  'PECCU_A19_T0001F002L01A02Z01C04.tif',
#  'PECCU_A19_T0001F002L01A02Z01C05.tif',
#  'PECCU_A19_T0001F002L01A03Z01C01.tif',
#  'PECCU_A19_T0001F003L01A01Z01C02.tif',
#  'PECCU_A19_T0001F003L01A01Z01C03.tif',
#  'PECCU_A19_T0001F003L01A02Z01C04.tif',
#  'PECCU_A19_T0001F003L01A02Z01C05.tif',
#  'PECCU_A19_T0001F003L01A03Z01C01.tif',
#  'PECCU_A19_T0001F004L01A01Z01C02.tif',
#  'PECCU_A19_T0001F004L01A01Z01C03.tif',
#  'PECCU_A19_T0001F004L01A02Z01C04.tif',
#  'PECCU_A19_T0001F004L01A02Z01C05.tif',
#  'PECCU_A19_T0001F004L01A03Z01C01.tif',
#  'PECCU_A19_T0001F005L01A01Z01C02.tif',
#  'PECCU_A19_T0001F005L01A01Z01C03.tif',
#  'PECCU_A19_T0001F005L01A02Z01C04.tif',
#  'PECCU_A19_T0001F005L01A02Z01C05.tif',
#  'PECCU_A19_T0001F005L01A03Z01C01.tif',
#  'PECCU_A19_T0001F006L01A01Z01C02.tif',
#  'PECCU_A19_T0001F006L01A01Z01C03.tif',
#  'PECCU_A19_T0001F006L01A02Z01C04.tif',
#  'PECCU_A19_T0001F006L01A02Z01C05.tif',
#  'PECCU_A19_T0001F006L01A03Z01C01.tif',
#  'PECCU_A19_T0001F007L01A01Z01C02.tif',
#  'PECCU_A19_T0001F007L01A01Z01C03.tif',
#  'PECCU_A19_T0001F007L01A02Z01C04.tif',
#  'PECCU_A19_T0001F007L01A02Z01C05.tif',
#  'PECCU_A19_T0001F007L01A03Z01C01.tif',
#  'PECCU_A19_T0001F008L01A01Z01C02.tif',
#  'PECCU_A19_T0001F008L01A01Z01C03.tif',
#  'PECCU_A19_T0001F008L01A02Z01C04.tif',
#  'PECCU_A19_T0001F008L01A02Z01C05.tif',
#  'PECCU_A19_T0001F008L01A03Z01C01.tif',
#  'PECCU_A19_T0001F009L01A01Z01C02.tif',
#  'PECCU_A19_T0001F009L01A01Z01C03.tif',
#  'PECCU_A19_T0001F009L01A02Z01C04.tif',
#  'PECCU_A19_T0001F009L01A02Z01C05.tif',
#  'PECCU_A19_T0001F009L01A03Z01C01.tif',
#  'PECCU_A20_T0001F001L01A01Z01C02.tif',
#  'PECCU_A20_T0001F001L01A01Z01C03.tif',
#  'PECCU_A20_T0001F001L01A02Z01C04.tif',
#  'PECCU_A20_T0001F001L01A02Z01C05.tif',
#  'PECCU_A20_T0001F001L01A03Z01C01.tif',
#  'PECCU_A20_T0001F002L01A01Z01C02.tif',
#  'PECCU_A20_T0001F002L01A01Z01C03.tif',
#  'PECCU_A20_T0001F002L01A02Z01C04.tif',
#  'PECCU_A20_T0001F002L01A02Z01C05.tif',
#  'PECCU_A20_T0001F002L01A03Z01C01.tif',
#  'PECCU_A20_T0001F003L01A01Z01C02.tif',
#  'PECCU_A20_T0001F003L01A01Z01C03.tif',
#  'PECCU_A20_T0001F003L01A02Z01C04.tif',
#  'PECCU_A20_T0001F003L01A02Z01C05.tif',
#  'PECCU_A20_T0001F003L01A03Z01C01.tif',
#  'PECCU_A20_T0001F004L01A01Z01C02.tif',
#  'PECCU_A20_T0001F004L01A01Z01C03.tif',
#  'PECCU_A20_T0001F004L01A02Z01C04.tif',
#  'PECCU_A20_T0001F004L01A02Z01C05.tif',
#  'PECCU_A20_T0001F004L01A03Z01C01.tif',
#  'PECCU_A20_T0001F005L01A01Z01C02.tif',
#  'PECCU_A20_T0001F005L01A01Z01C03.tif',
#  'PECCU_A20_T0001F005L01A02Z01C04.tif',
#  'PECCU_A20_T0001F005L01A02Z01C05.tif',
#  'PECCU_A20_T0001F005L01A03Z01C01.tif',
#  'PECCU_A20_T0001F006L01A01Z01C02.tif',
#  'PECCU_A20_T0001F006L01A01Z01C03.tif',
#  'PECCU_A20_T0001F006L01A02Z01C04.tif',
#  'PECCU_A20_T0001F006L01A02Z01C05.tif',
#  'PECCU_A20_T0001F006L01A03Z01C01.tif',
#  'PECCU_A20_T0001F007L01A01Z01C02.tif',
#  'PECCU_A20_T0001F007L01A01Z01C03.tif',
#  'PECCU_A20_T0001F007L01A02Z01C04.tif',
#  'PECCU_A20_T0001F007L01A02Z01C05.tif',
#  'PECCU_A20_T0001F007L01A03Z01C01.tif',
#  'PECCU_A20_T0001F008L01A01Z01C02.tif',
#  'PECCU_A20_T0001F008L01A01Z01C03.tif',
#  'PECCU_A20_T0001F008L01A02Z01C04.tif',
#  'PECCU_A20_T0001F008L01A02Z01C05.tif',
#  'PECCU_A20_T0001F008L01A03Z01C01.tif',
#  'PECCU_A20_T0001F009L01A01Z01C02.tif',
#  'PECCU_A20_T0001F009L01A01Z01C03.tif',
#  'PECCU_A20_T0001F009L01A02Z01C04.tif',
#  'PECCU_A20_T0001F009L01A02Z01C05.tif',
#  'PECCU_A20_T0001F009L01A03Z01C01.tif',
#  'PECCU_A21_T0001F001L01A01Z01C02.tif',
#  'PECCU_A21_T0001F001L01A01Z01C03.tif',
#  'PECCU_A21_T0001F001L01A02Z01C04.tif',
#  'PECCU_A21_T0001F001L01A02Z01C05.tif',
#  'PECCU_A21_T0001F001L01A03Z01C01.tif',
#  'PECCU_A21_T0001F002L01A01Z01C02.tif',
#  'PECCU_A21_T0001F002L01A01Z01C03.tif',
#  'PECCU_A21_T0001F002L01A02Z01C04.tif',
#  'PECCU_A21_T0001F002L01A02Z01C05.tif',
#  'PECCU_A21_T0001F002L01A03Z01C01.tif',
#  'PECCU_A21_T0001F003L01A01Z01C02.tif',
#  'PECCU_A21_T0001F003L01A01Z01C03.tif',
#  'PECCU_A21_T0001F003L01A02Z01C04.tif',
#  'PECCU_A21_T0001F003L01A02Z01C05.tif',
#  'PECCU_A21_T0001F003L01A03Z01C01.tif',
#  'PECCU_A21_T0001F004L01A01Z01C02.tif',
#  'PECCU_A21_T0001F004L01A01Z01C03.tif',
#  'PECCU_A21_T0001F004L01A02Z01C04.tif',
#  'PECCU_A21_T0001F004L01A02Z01C05.tif',
#  'PECCU_A21_T0001F004L01A03Z01C01.tif',
#  'PECCU_A21_T0001F005L01A01Z01C02.tif',
#  'PECCU_A21_T0001F005L01A01Z01C03.tif',
#  'PECCU_A21_T0001F005L01A02Z01C04.tif',
#  'PECCU_A21_T0001F005L01A02Z01C05.tif',
#  'PECCU_A21_T0001F005L01A03Z01C01.tif',
#  'PECCU_A21_T0001F006L01A01Z01C02.tif',
#  'PECCU_A21_T0001F006L01A01Z01C03.tif',
#  'PECCU_A21_T0001F006L01A02Z01C04.tif',
#  'PECCU_A21_T0001F006L01A02Z01C05.tif',
#  'PECCU_A21_T0001F006L01A03Z01C01.tif',
#  'PECCU_A21_T0001F007L01A01Z01C02.tif',
#  'PECCU_A21_T0001F007L01A01Z01C03.tif',
#  'PECCU_A21_T0001F007L01A02Z01C04.tif',
#  'PECCU_A21_T0001F007L01A02Z01C05.tif',
#  'PECCU_A21_T0001F007L01A03Z01C01.tif',
#  'PECCU_A21_T0001F008L01A01Z01C02.tif',
#  'PECCU_A21_T0001F008L01A01Z01C03.tif',
#  'PECCU_A21_T0001F008L01A02Z01C04.tif',
#  'PECCU_A21_T0001F008L01A02Z01C05.tif',
#  'PECCU_A21_T0001F008L01A03Z01C01.tif',
#  'PECCU_A21_T0001F009L01A01Z01C02.tif',
#  'PECCU_A21_T0001F009L01A01Z01C03.tif',
#  'PECCU_A21_T0001F009L01A02Z01C04.tif',
#  'PECCU_A21_T0001F009L01A02Z01C05.tif',
#  'PECCU_A21_T0001F009L01A03Z01C01.tif',
#  'PECCU_A22_T0001F001L01A01Z01C02.tif',
#  'PECCU_A22_T0001F001L01A01Z01C03.tif',
#  'PECCU_A22_T0001F001L01A02Z01C04.tif',
#  'PECCU_A22_T0001F001L01A02Z01C05.tif',
#  'PECCU_A22_T0001F001L01A03Z01C01.tif',
#  'PECCU_A22_T0001F002L01A01Z01C02.tif',
#  'PECCU_A22_T0001F002L01A01Z01C03.tif',
#  'PECCU_A22_T0001F002L01A02Z01C04.tif',
#  'PECCU_A22_T0001F002L01A02Z01C05.tif',
#  'PECCU_A22_T0001F002L01A03Z01C01.tif',
#  'PECCU_A22_T0001F003L01A01Z01C02.tif',
#  'PECCU_A22_T0001F003L01A01Z01C03.tif',
#  'PECCU_A22_T0001F003L01A02Z01C04.tif',
#  'PECCU_A22_T0001F003L01A02Z01C05.tif',
#  'PECCU_A22_T0001F003L01A03Z01C01.tif',
#  'PECCU_A22_T0001F004L01A01Z01C02.tif',
#  'PECCU_A22_T0001F004L01A01Z01C03.tif',
#  'PECCU_A22_T0001F004L01A02Z01C04.tif',
#  'PECCU_A22_T0001F004L01A02Z01C05.tif',
#  'PECCU_A22_T0001F004L01A03Z01C01.tif',
#  'PECCU_A22_T0001F005L01A01Z01C02.tif',
#  'PECCU_A22_T0001F005L01A01Z01C03.tif',
#  'PECCU_A22_T0001F005L01A02Z01C04.tif',
#  'PECCU_A22_T0001F005L01A02Z01C05.tif',
#  'PECCU_A22_T0001F005L01A03Z01C01.tif',
#  'PECCU_A22_T0001F006L01A01Z01C02.tif',
#  'PECCU_A22_T0001F006L01A01Z01C03.tif',
#  'PECCU_A22_T0001F006L01A02Z01C04.tif',
#  'PECCU_A22_T0001F006L01A02Z01C05.tif',
#  'PECCU_A22_T0001F006L01A03Z01C01.tif',
#  'PECCU_A22_T0001F007L01A01Z01C02.tif',
#  'PECCU_A22_T0001F007L01A01Z01C03.tif',
#  'PECCU_A22_T0001F007L01A02Z01C04.tif',
#  'PECCU_A22_T0001F007L01A02Z01C05.tif',
#  'PECCU_A22_T0001F007L01A03Z01C01.tif',
#  'PECCU_A22_T0001F008L01A01Z01C02.tif',
#  'PECCU_A22_T0001F008L01A01Z01C03.tif',
#  'PECCU_A22_T0001F008L01A02Z01C04.tif',
#  'PECCU_A22_T0001F008L01A02Z01C05.tif',
#  'PECCU_A22_T0001F008L01A03Z01C01.tif',
#  'PECCU_A22_T0001F009L01A01Z01C02.tif',
#  'PECCU_A22_T0001F009L01A01Z01C03.tif',
#  'PECCU_A22_T0001F009L01A02Z01C04.tif',
#  'PECCU_A22_T0001F009L01A02Z01C05.tif',
#  'PECCU_A22_T0001F009L01A03Z01C01.tif',
#  'PECCU_A23_T0001F001L01A01Z01C02.tif',
#  ...]

# %%
lst = []

for i, image in enumerate(os.listdir(fpath)):

    imgpath = os.path.join(fpath, image)


    if imgpath.endswith("tif"):

            head, tail = os.path.split(imgpath)

            if "PECCU" in tail:


                lst.append(tail)


    keys = list(channels.keys())
    values = list(channels.values())


    ch1 = [s for s in lst if 'C01.' in s]
    ch2 = [s for s in lst if 'C02.' in s]
    ch3 = [s for s in lst if 'C03.' in s]
    ch4 = [s for s in lst if 'C04.' in s]
    ch5 = [s for s in lst if 'C05.' in s]
    ch6 = [s for s in lst if 'C06.' and 'Z06' in s]
    
    if ch6 is None:
        
        zippedlist = list(zip(ch1, ch2, ch3, ch4, ch5, ch6))
        
        


    
    
    

zippedlist


#     df = pd.DataFrame(zippedlist, columns=["FileName_"+chname for chname in values])

#     path_columns = { c : fpath for c in ["PathName_"+chname for chname in values]}

#     df = df.assign(**path_columns)


#     wellname = df['FileName_OrigDNA'].tolist()



#     pattern = re.compile(".+_(?P<Well>\w+)_.+F0(?P<site>\d)")



#     match = [pattern.match(i) for i in wellname]
#     well = [r.group("Well") for r in match]
#     site= [f.group("site") for f in match]

#     site_0= [f.group("site") for f in match]

#     site = [(lambda x: x.strip('0') if isinstance(x,str) and len(x) != 1 else x)(x) for x in site_0]



#     df['Metadata_Well'] = well
#     df['Metadata_Site'] = site
#     df['Metadata_Plate'] = plate
# Out:
# []

# %%
## Channel mapping

channels = {'ch1':"OrigDNA",
    'ch2':"OrigER",
    'ch3':"OrigActin_Golgi",
    'ch4':"OrigMito",
    'ch5':"OrigNucleoli",
    'ch6':"OrigBrightField",
    }

# %%
fpath = plist_path[3]

outpath = outpath_list[3]



plate = os.path.split(outpath)[-1]

print(fpath)
print(outpath)
print(plate)
# Out:
# /home/ubuntu/bucket/projects/2019_07_11_JUMP-CP-pilots/2020_11_16_Scope1_YokogawaUS/BRO0117033-3D-2x2x1-singleplane-20x_20201015_161709/PECCU
# /home/ubuntu/bucket/projects/2019_07_11_JUMP-CP-pilots/workspace/load_data_csv/2020_11_16_Scope1_YokogawaUS/BRO0117033_3D_2x2x1_singleplane_20x_20201015_161709
# BRO0117033_3D_2x2x1_singleplane_20x_20201015_161709

# %%
def load_data(channels):
    
    lst = []

    for i, image in enumerate(os.listdir(fpath)):
    
        imgpath = os.path.join(fpath, image)


        if imgpath.endswith("tif"):

                head, tail = os.path.split(imgpath)
                
                if "PECCU" in tail:
            
        
                    lst.append(tail)


        keys = list(channels.keys())
        values = list(channels.values())


        ch1 = [s for s in lst if 'C01.' in s]
        ch2 = [s for s in lst if 'C02.' in s]
        ch3 = [s for s in lst if 'C03.' in s]
        ch4 = [s for s in lst if 'C04.' in s]
        ch5 = [s for s in lst if 'C05.' in s]
        ch6 = [s for s in lst if 'C06.' and 'Z06' in s]
        
        
        
        if len(ch6) == 0:

            zippedlist = list(zip(ch1, ch2, ch3, ch4, ch5))
            
            df = pd.DataFrame(zippedlist, columns=["FileName_"+chname for chname in values])

            path_columns = { c : fpath for c in ["PathName_"+chname for chname in values]}

            df = df.assign(**path_columns)


            wellname = df['FileName_OrigDNA'].tolist()



            pattern = re.compile(".+_(?P<Well>\w+)_.+F0(?P<site>\d)")



            match = [pattern.match(i) for i in wellname]
            well = [r.group("Well") for r in match]
            site= [f.group("site") for f in match]

            site_0= [f.group("site") for f in match]

            site = [(lambda x: x.strip('0') if isinstance(x,str) and len(x) != 1 else x)(x) for x in site_0]



            df['Metadata_Well'] = well
            df['Metadata_Site'] = site
            df['Metadata_Plate'] = plate



            colnames = ['FileName_'+values[0], 'PathName_'+values[0],
                        'FileName_'+values[1], 'PathName_'+values[1],
                        'FileName_'+values[2], 'PathName_'+values[2],
                        'FileName_'+values[3], 'PathName_'+values[3],
                        'FileName_'+values[4], 'PathName_'+values[4],
                        'Metadata_Plate','Metadata_Well', 
                        'Metadata_Site']


        else:

            zippedlist = list(zip(ch1, ch2, ch3, ch4, ch5, ch6))
            
            df = pd.DataFrame(zippedlist, columns=["FileName_"+chname for chname in values])

            path_columns = { c : fpath for c in ["PathName_"+chname for chname in values]}

            df = df.assign(**path_columns)


            wellname = df['FileName_OrigDNA'].tolist()



            pattern = re.compile(".+_(?P<Well>\w+)_.+F0(?P<site>\d)")



            match = [pattern.match(i) for i in wellname]
            well = [r.group("Well") for r in match]
            site= [f.group("site") for f in match]

            site_0= [f.group("site") for f in match]

            site = [(lambda x: x.strip('0') if isinstance(x,str) and len(x) != 1 else x)(x) for x in site_0]



            df['Metadata_Well'] = well
            df['Metadata_Site'] = site
            df['Metadata_Plate'] = plate



            colnames = ['FileName_'+values[0], 'PathName_'+values[0],
                        'FileName_'+values[1], 'PathName_'+values[1],
                        'FileName_'+values[2], 'PathName_'+values[2],
                        'FileName_'+values[3], 'PathName_'+values[3],
                        'FileName_'+values[4], 'PathName_'+values[4],
                        'FileName_'+values[5], 'PathName_'+values[5],
                        'Metadata_Plate','Metadata_Well', 
                        'Metadata_Site','Metadata_Zplane']




        
   
    
    return df.reindex(columns=colnames)

df = load_data(channels) 

df.to_csv(outpath + "/" + 'load_data.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-30-584c566cb6d1> in <module>
#     127     return df.reindex(columns=colnames)
#     128
# --> 129 df = load_data(channels)
#     130
#     131 df.to_csv(outpath + "/" + 'load_data.csv', index=False)
#
# <ipython-input-30-584c566cb6d1> in load_data(channels)
#      35             zippedlist = list(zip(ch1, ch2, ch3, ch4, ch5))
#      36
# ---> 37             df = pd.DataFrame(zippedlist, columns=["FileName_"+chname for chname in values])
#      38
#      39             path_columns = { c : fpath for c in ["PathName_"+chname for chname in values]}
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     433                     if is_named_tuple(data[0]) and columns is None:
#     434                         columns = data[0]._fields
# --> 435                     arrays, columns = to_arrays(data, columns, dtype=dtype)
#     436                     columns = ensure_index(columns)
#     437
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in to_arrays(data, columns, coerce_float, dtype)
#     402     if isinstance(data[0], (list, tuple)):
#     403         return _list_to_arrays(data, columns, coerce_float=coerce_float,
# --> 404                                dtype=dtype)
#     405     elif isinstance(data[0], compat.Mapping):
#     406         return _list_of_dict_to_arrays(data, columns,
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in _list_to_arrays(data, columns, coerce_float, dtype)
#     434         content = list(lib.to_object_array(data).T)
#     435     return _convert_object_array(content, columns, dtype=dtype,
# --> 436                                  coerce_float=coerce_float)
#     437
#     438
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in _convert_object_array(content, columns, coerce_float, dtype)
#     490             raise AssertionError('{col:d} columns passed, passed data had '
#     491                                  '{con} columns'.format(col=len(columns),
# --> 492                                                         con=len(content)))
#     493
#     494     # provide soft conversion of object dtypes
#
# AssertionError: 6 columns passed, passed data had 5 columns

# %%
illum_channels = list(channels.values())
# Out:
# ['OrigDNA',
#  'OrigER',
#  'OrigActin_Golgi',
#  'OrigMito',
#  'OrigNucleoli',
#  'OrigBrightField']

# %%
def load_data_with_illum(channels):
    
    illum_channels = list(channels.values())
    
    if len(illum_channels == 6):

        illum = [s.replace("Orig", "Illum") for s in illum_channels]

        df['FileName_'+illum[0]] = plate + '_' + illum[0] + '.npy'

        df['PathName_'+illum[0]] = os.path.join(batchpath, 'illum', plate)


        df['FileName_'+illum[1]] = plate + '_' + illum[1] + '.npy'

        df['PathName_'+illum[1]] = os.path.join(batchpath, 'illum', plate)


        df['FileName_'+illum[2]] = plate + '_' + illum[2] + '.npy'

        df['PathName_'+illum[2]] = os.path.join(batchpath, 'illum', plate)



        df['FileName_'+illum[3]] = plate + '_' + illum[3] + '.npy'

        df['PathName_'+illum[3]] = os.path.join(batchpath, 'illum', plate)


        df['FileName_'+illum[4]] = plate + '_' + illum[4] + '.npy'

        df['PathName_'+illum[4]] = os.path.join(batchpath, 'illum', plate)

        df['FileName_'+illum[5]] = plate + '_' + illum[5] + '.npy'

        df['PathName_'+illum[5]] = os.path.join(batchpath, 'illum', plate)
    
    else:
        
        illum = [s.replace("Orig", "Illum") for s in illum_channels]

        df['FileName_'+illum[0]] = plate + '_' + illum[0] + '.npy'

        df['PathName_'+illum[0]] = os.path.join(batchpath, 'illum', plate)


        df['FileName_'+illum[1]] = plate + '_' + illum[1] + '.npy'

        df['PathName_'+illum[1]] = os.path.join(batchpath, 'illum', plate)


        df['FileName_'+illum[2]] = plate + '_' + illum[2] + '.npy'

        df['PathName_'+illum[2]] = os.path.join(batchpath, 'illum', plate)



        df['FileName_'+illum[3]] = plate + '_' + illum[3] + '.npy'

        df['PathName_'+illum[3]] = os.path.join(batchpath, 'illum', plate)


        df['FileName_'+illum[4]] = plate + '_' + illum[4] + '.npy'

        df['PathName_'+illum[4]] = os.path.join(batchpath, 'illum', plate)


       
    
    return df.reindex()

illum = load_data_with_illum(channels)

illum.to_csv(outpath + "/" + 'load_data_with_illum.csv', index=False)
